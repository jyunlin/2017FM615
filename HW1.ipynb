# %% [markdown]
# # 如何使用numpy 簡單求取百分位數

# %%
import numpy as np

# %%
a = [154, 400, 1124, 82, 94, 108]

# %%
print (np.percentile(a,95)) # gives the 95th percentil
# Out:
# 943.0

# %% [markdown]
# # 利用pandas 讀取stockq股價

# %%
import pandas as pd

# %%
url = 'http://www.stockq.org/market/asia.php'

# %%
table = pd.read_html(url)[4]
table = table.drop(table.columns[[0,1,2,3,4,36]],axis=0) #刪除多的列數
table = table.drop(table.columns[9:296],axis=1)#刪除多餘的行數

# %%
table
# Out:
#          0         1       2       3         4         5         6       7  \
# 5      紐西蘭   8473.14    9.15   0.11%   8491.70   8461.63   8466.03   0.89%
# 6     澳洲股市  6077.149  -24.22  -0.40%   6101.40   6055.10   6101.40  -1.46%
# 7    日經225   21968.1  144.07   0.66%  21968.10  21700.78  21742.45  -3.50%
# 8     東證一部   1751.03    9.73   0.56%   1751.03   1731.58   1734.31  -3.66%
# 9     東證二部   7366.06   53.37   0.73%   7366.06   7283.16   7287.29   1.24%
# 10  JASDAQ    180.39    2.44   1.37%    180.39    177.84     2.96%   15:00
# 11    韓國股市   2494.49   10.37   0.42%   2494.49   2478.76   2483.05   1.09%
# 12    台灣加權  11095.63   93.53   0.85%  11095.63  11014.87  11022.15   4.25%
# 13    台灣店頭    153.33    1.09   0.72%    153.72    152.47     3.24%   13:33
# 14    上海綜合  3310.239  -16.46  -0.49%   3333.88   3307.38   3324.12   0.09%
# 15    上海A股  3466.914  -17.24  -0.49%   3491.71   3463.91   3481.45   0.10%
# ...
